# %%
tablero = [{'inicio':20000},
           {'canada':{'valor_de_la_propiedad':12000, 'renta':3600, 'costo_casa':2400, 'costo_hotel':6000, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
          {'peru':{'valor_de_la_propiedad':15000, 'renta':4500, 'costo_casa':3000, 'costo_hotel':7500, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
            {'brasil':{'valor_de_la_propiedad':23000, 'renta':6900, 'costo_casa':4600, 'costo_hotel':11500, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
          {'carcel':-30000}, 
           {'portugal':{'valor_de_la_propiedad':30000, 'renta':9000, 'costo_casa':6000, 'costo_hotel':15000, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
          {'italia':{'valor_de_la_propiedad':40000, 'renta':12000, 'costo_casa':8000, 'costo_hotel':20000, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
          {'finlandia':{'valor_de_la_propiedad':26000, 'renta':7800, 'costo_casa':5200, 'costo_hotel':13000, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
           {'sigue_adelante':0},
          {'rusia':{'valor_de_la_propiedad':18000, 'renta':5400, 'costo_casa':3600, 'costo_hotel':9000, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
          {'china':{'valor_de_la_propiedad':25000, 'renta':7500, 'costo_casa':5000, 'costo_hotel':12500, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
          {'japon':{'valor_de_la_propiedad':41000, 'renta':12300, 'costo_casa':8200, 'costo_hotel':20500, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
          {'ir_carcel':0},
          {'argelia':{'valor_de_la_propiedad':32000, 'renta':9600, 'costo_casa':6400, 'costo_hotel':16000, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
          {'congo':{'valor_de_la_propiedad':35000, 'renta':10500, 'costo_casa':7000, 'costo_hotel':17500, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
          {'sudafrica':{'valor_de_la_propiedad':37000, 'renta':11100, 'costo_casa':7400, 'costo_hotel':18500, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}}]

[[k,v]] = tablero[1].items() #k guarda el nombre de la casilla y v guarda el diccionario de sus caracteristicas
a = list(v.values())
print(type(a))
print(a)

b = v['valor_de_la_propiedad']
print(type(b))
print(b)
# Out:
# <class 'list'>
# [12000, 3600, 2400, 6000, 0, 0, 0, [0, 0]]
# <class 'int'>
# 12000

# %%
#el usuario define el numero de turnos a jugar
#el turno discierne entre las casillas especiales
import random

tablero = [{'inicio':20000},
           {'canada':{'valor_de_la_propiedad':12000, 'renta':3600, 'costo_casa':2400, 'costo_hotel':6000, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
          {'peru':{'valor_de_la_propiedad':15000, 'renta':4500, 'costo_casa':3000, 'costo_hotel':7500, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
            {'brasil':{'valor_de_la_propiedad':23000, 'renta':6900, 'costo_casa':4600, 'costo_hotel':11500, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
          {'carcel':-30000}, 
           {'portugal':{'valor_de_la_propiedad':30000, 'renta':9000, 'costo_casa':6000, 'costo_hotel':15000, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
          {'italia':{'valor_de_la_propiedad':40000, 'renta':12000, 'costo_casa':8000, 'costo_hotel':20000, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
          {'finlandia':{'valor_de_la_propiedad':26000, 'renta':7800, 'costo_casa':5200, 'costo_hotel':13000, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
           {'sigue_adelante':0},
          {'rusia':{'valor_de_la_propiedad':18000, 'renta':5400, 'costo_casa':3600, 'costo_hotel':9000, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
          {'china':{'valor_de_la_propiedad':25000, 'renta':7500, 'costo_casa':5000, 'costo_hotel':12500, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
          {'japon':{'valor_de_la_propiedad':41000, 'renta':12300, 'costo_casa':8200, 'costo_hotel':20500, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
          {'ir_carcel':0},
          {'argelia':{'valor_de_la_propiedad':32000, 'renta':9600, 'costo_casa':6400, 'costo_hotel':16000, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
          {'congo':{'valor_de_la_propiedad':35000, 'renta':10500, 'costo_casa':7000, 'costo_hotel':17500, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
          {'sudafrica':{'valor_de_la_propiedad':37000, 'renta':11100, 'costo_casa':7400, 'costo_hotel':18500, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}}]

#jugadores = [{'jugador1':{'dinero':150000, 'casilla':k}},{'jugador2':{'dinero':150000, 'casilla':tablero[0]}}]


###### Ponemos las fichas en la casilla de salida
n = [0, 'inicio', 150000]
m = [0, 'inicio', 150000]
tirada_j1 = 0
tirada_j2 = 0
casilla_actual_j1 = tablero[tirada_j1]
casilla_actual_j2 = tablero[tirada_j2]

###### Turno jugador1
###### Movimiento por tirar el dado
def mov_j1(tirada_j1):
    print('Turno jugador 1')
    dado = random.randint(1,4) #dado normal del 1 al 4
    tirada_j1 = (tirada_j1 + dado)%16
    [[k,v]] = tablero[tirada_j1].items() #k guarda el nombre de la casilla y v guarda el diccionario de sus caracteristicas
    print('El dado salió', dado, '\nEl jugador 1 llegó a la casilla', k)
    
    #Ver si está en una casilla especial
    if tirada_j1 == 0:
        dinero = n[2] + 20000
    elif tirada_j1 == 4:
        dinero = n[2] - 50000 #la carcel te quita 50000 (no se como saltar el turno)
    elif tirada_j1 == 8:
        dinero = n[2]
    elif tirada_j1 == 12:
        tirada_j1 = 4
        print('¡Te vas a la cárcel!')
        dinero = n[2] - 50000 #la carcel te quita 50000 (no se como saltar el turno)
    else: dinero = n[2]
    
    return [tirada_j1,k,dinero]

def mov_j2(tirada_j2):
    print('Turno jugador 2')
    dado = random.randint(1,4) #dado normal del 1 al 4
    tirada_j2 = (tirada_j2 + dado)%16
    [[k,v]] = tablero[tirada_j2].items() #k guarda el nombre de la casilla y v guarda el diccionario de sus caracteristicas
    print('El dado salió', dado, '\nEl jugador 2 llegó a la casilla', k)
    
    #Ver si está en una casilla especial
    if tirada_j2 == 0:
        dinero = m[2] + 20000
    elif tirada_j2 == 4:
        dinero = m[2] - 50000 #la carcel te quita 50000 (no se como saltar el turno)
    elif tirada_j2 == 8:
        dinero = m[2]
    elif tirada_j2 == 12:
        tirada_j2 = 4
        print('¡Te vas a la cárcel!')
        dinero = m[2] - 50000 #la carcel te quita 50000 (no se como saltar el turno)
    else: dinero = m[2]    
    
    return [tirada_j2,k,dinero]

for i in range(1):
    n = mov_j1(n[0])
    print(n)
    m = mov_j2(m[0])
    print(m)
# Out:
# Turno jugador 1
# El dado salió 1
# El jugador 1 llegó a la casilla canada
# [1, 'canada', 150000]
# Turno jugador 2
# El dado salió 2
# El jugador 2 llegó a la casilla peru
# [2, 'peru', 150000]

# %%
#el usuario define el numero de turnos a jugar
#el turno discierne entre la casilla inicio y las demás
#el turno llama al inicio de la funcion de compra
import random

tablero = [{'inicio':20000},
           {'canada':{'valor_de_la_propiedad':12000, 'renta':3600, 'costo_casa':2400, 'costo_hotel':6000, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
          {'peru':{'valor_de_la_propiedad':15000, 'renta':4500, 'costo_casa':3000, 'costo_hotel':7500, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
            {'brasil':{'valor_de_la_propiedad':23000, 'renta':6900, 'costo_casa':4600, 'costo_hotel':11500, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
          {'carcel':-30000}, 
           {'portugal':{'valor_de_la_propiedad':30000, 'renta':9000, 'costo_casa':6000, 'costo_hotel':15000, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
          {'italia':{'valor_de_la_propiedad':40000, 'renta':12000, 'costo_casa':8000, 'costo_hotel':20000, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
          {'finlandia':{'valor_de_la_propiedad':26000, 'renta':7800, 'costo_casa':5200, 'costo_hotel':13000, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
           {'sigue_adelante':0},
          {'rusia':{'valor_de_la_propiedad':18000, 'renta':5400, 'costo_casa':3600, 'costo_hotel':9000, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
          {'china':{'valor_de_la_propiedad':25000, 'renta':7500, 'costo_casa':5000, 'costo_hotel':12500, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
          {'japon':{'valor_de_la_propiedad':41000, 'renta':12300, 'costo_casa':8200, 'costo_hotel':20500, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
          {'ir_carcel':0},
          {'argelia':{'valor_de_la_propiedad':32000, 'renta':9600, 'costo_casa':6400, 'costo_hotel':16000, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
          {'congo':{'valor_de_la_propiedad':35000, 'renta':10500, 'costo_casa':7000, 'costo_hotel':17500, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
          {'sudafrica':{'valor_de_la_propiedad':37000, 'renta':11100, 'costo_casa':7400, 'costo_hotel':18500, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}}]

#jugadores = [{'jugador1':{'dinero':150000, 'casilla':k}},{'jugador2':{'dinero':150000, 'casilla':tablero[0]}}]


###### Ponemos las fichas en la casilla de salida
n = [0, 'inicio', 150000]
m = [0, 'inicio', 150000]
tirada_j1 = 0
tirada_j2 = 0
casilla_actual_j1 = tablero[tirada_j1]
casilla_actual_j2 = tablero[tirada_j2]

###### Turno jugador1
###### Movimiento por tirar el dado
def mov_j1(tirada_j1):
    print('Turno jugador 1')
    dado = random.randint(1,4) #dado normal del 1 al 4
    tirada_j1 = (tirada_j1 + dado)%16
    [[k,v]] = tablero[tirada_j1].items() #k guarda el nombre de la casilla y v guarda el diccionario de sus caracteristicas
    print('El dado salió', dado, '\nEl jugador 1 llegó a la casilla', k)
    
    ##datos_casilla = list(v.values()) #lista de valores de la casilla donde esta el jugador
    dinero = n[2]
    
    #Ver si está en la casilla inicio y darle dinero
    paises = [1,2,3,5,6,7,9,10,11,13,14,15]
    if tirada_j1 == 0:
        dinero = n[2] + 20000
    elif tirada_j1 in paises:
        propiedad(1, tirada_j1, v['dueño']) ##mejor usamos los datos del diccionario yey
    else: dinero = n[2]
    
    return [tirada_j1,k,dinero]

def mov_j2(tirada_j2):
    print('Turno jugador 2')
    dado = random.randint(1,4) #dado normal del 1 al 4
    tirada_j2 = (tirada_j2 + dado)%16
    [[k,v]] = tablero[tirada_j2].items() #k guarda el nombre de la casilla y v guarda el diccionario de sus caracteristicas
    print('El dado salió', dado, '\nEl jugador 2 llegó a la casilla', k)
    
    #Ver si está en la casilla inicio y darle dinero
    if tirada_j2 == 0:
        dinero = m[2] + 20000
    else: dinero = m[2]    
    
    return [tirada_j2,k,dinero]

###### Funcion de compras
def propiedad (jugador, posicion, dueño):
    
    if dueño == 0:
        respuesta_comprar = int(input('¿Quieres comprar la propiedad? Presiona 1 para Sí, 2 para -No-.'))
        dinero = n[2]
    return

##################### correr el juego
for i in range(1):
    n = mov_j1(n[0])
    print(n)
    m = mov_j2(m[0])
    print(m)
# Out:
# Turno jugador 1
# El dado salió 2
# El jugador 1 llegó a la casilla peru
# ¿Quieres comprar la propiedad? Presiona 1 para Sí, 2 para -No-.2
# [2, 'peru', 150000]
# Turno jugador 2
# El dado salió 4
# El jugador 2 llegó a la casilla carcel
# [4, 'carcel', 150000]

# %%
#el usuario define el numero de turnos a jugar
#el turno discierne entre las casillas especiales
#el turno llama a la funcion de compra (en construcción)
import random

tablero = [{'inicio':20000},
           {'canada':{'valor_de_la_propiedad':12000, 'renta':3600, 'costo_casa':2400, 'costo_hotel':6000, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
          {'peru':{'valor_de_la_propiedad':15000, 'renta':4500, 'costo_casa':3000, 'costo_hotel':7500, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
            {'brasil':{'valor_de_la_propiedad':23000, 'renta':6900, 'costo_casa':4600, 'costo_hotel':11500, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
          {'carcel':-30000}, 
           {'portugal':{'valor_de_la_propiedad':30000, 'renta':9000, 'costo_casa':6000, 'costo_hotel':15000, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
          {'italia':{'valor_de_la_propiedad':40000, 'renta':12000, 'costo_casa':8000, 'costo_hotel':20000, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
          {'finlandia':{'valor_de_la_propiedad':26000, 'renta':7800, 'costo_casa':5200, 'costo_hotel':13000, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
           {'sigue_adelante':0},
          {'rusia':{'valor_de_la_propiedad':18000, 'renta':5400, 'costo_casa':3600, 'costo_hotel':9000, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
          {'china':{'valor_de_la_propiedad':25000, 'renta':7500, 'costo_casa':5000, 'costo_hotel':12500, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
          {'japon':{'valor_de_la_propiedad':41000, 'renta':12300, 'costo_casa':8200, 'costo_hotel':20500, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
          {'ir_carcel':0},
          {'argelia':{'valor_de_la_propiedad':32000, 'renta':9600, 'costo_casa':6400, 'costo_hotel':16000, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
          {'congo':{'valor_de_la_propiedad':35000, 'renta':10500, 'costo_casa':7000, 'costo_hotel':17500, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}},
          {'sudafrica':{'valor_de_la_propiedad':37000, 'renta':11100, 'costo_casa':7400, 'costo_hotel':18500, 'dueño':0, 'casas':0, 'hoteles':0, 'quien_esta':[0,0]}}]

#jugadores = [{'jugador1':{'dinero':150000, 'casilla':k}},{'jugador2':{'dinero':150000, 'casilla':tablero[0]}}]


###### Ponemos las fichas en la casilla de salida
n = [0, 'inicio', 150000]
m = [0, 'inicio', 150000]
tirada_j1 = 0
tirada_j2 = 0
casilla_actual_j1 = tablero[tirada_j1]
casilla_actual_j2 = tablero[tirada_j2]

###### Turno jugador1
###### Movimiento por tirar el dado
def mov_j1(tirada_j1):
    print('Turno jugador 1')
    dado = random.randint(1,4) #dado normal del 1 al 4
    tirada_j1 = (tirada_j1 + dado)%16
    [[k,v]] = tablero[tirada_j1].items() #k guarda el nombre de la casilla y v guarda el diccionario de sus caracteristicas
    print('El dado salió', dado, '\nEl jugador 1 llegó a la casilla', k)
    
    #datos_casilla = list(v.values()) #lista de valores de la casilla donde esta el jugador ##quitar
    #[valor propiedad, renta, costo casa, costo hotel, dueño, casas, hoteles, quién está]
    dinero = n[2] #para que no me marque error de que la llamo antes de definirla
    
    #Ver si está en una casilla especial
    paises = [1,2,3,5,6,7,9,10,11,13,14,15]
    if tirada_j1 == 0:
        dinero = n[2] + 20000
    elif tirada_j1 == 4:
        dinero = n[2] - 50000 #la carcel te quita 50000 (no se como saltar el turno)
    elif tirada_j1 == 8:
        dinero = n[2]
    elif tirada_j1 == 12:
        tirada_j1 = 4
        print('¡Te vas a la cárcel!')
        dinero = n[2] - 50000 #la carcel te quita 50000 (no se como saltar el turno)
    elif tirada_j1 in paises:
        propiedad(1, tirada_j1, v['dueño'])
    else: dinero = n[2]
    
    return [tirada_j1,k,dinero]

def mov_j2(tirada_j2):
    print('Turno jugador 2')
    dado = random.randint(1,4) #dado normal del 1 al 4
    tirada_j2 = (tirada_j2 + dado)%16
    [[k,v]] = tablero[tirada_j2].items() #k guarda el nombre de la casilla y v guarda el diccionario de sus caracteristicas
    print('El dado salió', dado, '\nEl jugador 2 llegó a la casilla', k)
    
    #Ver si está en una casilla especial
    if tirada_j2 == 0:
        dinero = m[2] + 20000
    elif tirada_j2 == 4:
        dinero = m[2] - 50000 #la carcel te quita 50000 (no se como saltar el turno)
    elif tirada_j2 == 8:
        dinero = m[2]
    elif tirada_j2 == 12:
        tirada_j2 = 4
        print('¡Te vas a la cárcel!')
        dinero = m[2] - 50000 #la carcel te quita 50000 (no se como saltar el turno)
    else: dinero = m[2]    
    
    return [tirada_j2,k,dinero]
###### Funcion de compras
def propiedad (jugador, posicion, dueño):
    [[k,v]] = tablero[tirada_j1].items() #k guarda el nombre de la casilla y v guarda el diccionario de sus caracteristicas
    dinero = n[2]
    if dueño == 0:
        respuesta_comprar = int(input('¿Quieres comprar la propiedad? Presiona 1 para Sí, 2 para -No-.'))
        dinero = dinero + 1 #v['valor_de_la_propiedad']
    return

##################### correr el juego
for i in range(1):
    n = mov_j1(n[0])
    print(n)
    m = mov_j2(m[0])
    print(m)
