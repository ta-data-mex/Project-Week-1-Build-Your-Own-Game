# %%
#### Para Windows
import winsound

#Para mac
#import os
#os.system("afplay Sound.wav&") 

import time
import random
import pprint

from IPython.display import display
from PIL import Image


#Determinando Variables

herramientas = ["silla","llave 1","llave 2","foto"]

puerta = "0,2,5,7"

path="Escape.jpg"
display(Image.open(path))   

winsound.PlaySound("Sound",winsound.SND_ASYNC | winsound.SND_LOOP)
#os.system("afplay Sound.wav&") 

def displayIntro():
    print("Bienvenido.")
    print()
    time.sleep(2)
    print("Has despertado en una habitación a obscuras,")
    path="Dark.jpg"
    display(Image.open(path))
    time.sleep(2)
    print("tu pie derecho está encadenado a la pared detrás de ti.")
    print()
    time.sleep(2)
    print("No puedes ver nada pero sientes una silla a tu lado.")
    print()
    time.sleep(2)
    print("Comienzas a tocar a tu alrededor para reconocer el espacio.")
    print()
    time.sleep(2)
    print("Sientes el interruptor en una de las paredes y logras encender")
    time.sleep(1)
    print("una luz color ambar que ilumina muy poco.")
    path="Hands.jpg"
    display(Image.open(path))
    print()
    time.sleep(3)
    print("Tus ojos se acostumbran lentamente a la nueva luz y te das cuenta")
    time.sleep(1)
    print("que algo debajo de ti se mueve, es una tabla suelta en el piso.")
    path="Piso.jpg"
    display(Image.open(path))
    time.sleep(2)
    print()

displayIntro()  

choice_0 = input("¿Qué quieres hacer? quitar la tabla (1) o sentarte en la silla(2): ")

while choice_0 != "1":
    print()
    print("Te sientes confundido y no puedes ver mucho, sigues algo aturdido,")
    time.sleep(2)
    print("te preguntas cómo es que llegaste aquí.")
    print()
    time.sleep(2)
    print("Miras la larga y pesada cadena que te aprisiona y mientras tiras de ella")
    time.sleep(1)
    print("notas la tabla suelta del piso, parece un contenedor.")
    time.sleep(2)
    print()
    choice_0 = input("Quieres quitar la tabla (1) o seguir sentado (2)?: ")

print()
time.sleep(2)
print("Quitas la tabla y remueves el contenido, encuentras polvo, pedazos de tela")
print("una llave y una foto.")
time.sleep(3)
print()

choice_1 = input("Quieres ver la foto o quieres tomar la llave(foto/llave): ")

while choice_1 != "llave":
    print()
    time.sleep(2)
    print("Ves la foto de una familia feliz con un hijo pequeño")
    time.sleep(2)
    path="Family.jpg"
    display(Image.open(path))
    print("luego de un rato mirando la foto te das cuenta de que reconoces el lugar")
    time.sleep(2)
    print("es la casa de tu infancia y las personas en la foto son de tu familia")
    time.sleep(2)
    print("Necesitas salir lo antes posible de ahí, corren peligro.")
    time.sleep(3)
    print()
    choice_1=input("¿Quieres seguir viendo la foto o tomas la llave? (foto/llave): ")
    
# segunda desición

print()
path="Key.jpg"
display(Image.open(path))
time.sleep(4)
print("Tomas la llave e intentas abrir la cadena ¡TE HAS LIBERADO!")
time.sleep(2)
path="Chains.jpg"
display(Image.open(path))
print()
time.sleep(1)
print("Miras a tu al rededor y ves una mesa a la izquierda, te acercas, tal vez encuentres algo.")
time.sleep(2)
print()
print("Examinas el espacio y no encuentras nada útil, pero sientes algo raro debajo de la mesa. ")
time.sleep(2)
print("encuentras una llave pegada con cinta.")
print()
time.sleep(3)
choice_2=input("Que quieres hacer? explorar o intentar salir (explorar/salir): ")

while choice_2 != "explorar":
    print()
    time.sleep(2)
    print("Intentas salir pero no puedes, hay una cajita con números en lugar de cerrojo")
    time.sleep(2)
    print("La puerta sólo abrirá con un código.")
    time.sleep(1)
    print()
    print("Necesitas encontrar otra manera urgentemente ¡Tu familia espera por ti! ")
    time.sleep(3)
    print()
    choice_2=input("¿Quieres volver a explorar?(explorar/salir): ")
    
print()
print("Comienzas a examinar toda la habitación con detenimiento")
time.sleep(1)
print("y notas una especie de caja en el techo. Parece tener una cerradura")
time.sleep(3)
print()
path="Caja.jpg"
display(Image.open(path))
time.sleep(1)
print()
choice_3 = input("¿Quieres ver tus herramientas?(si/no): ")

while choice_3 != "si":
    print()
    time.sleep(2)
    print("Examinas la habitación, está fría y poco iluminada.")
    time.sleep(2)
    print("Las habitaciones vacías te ponen de los nervios.")
    time.sleep(2)
    print("Extrañas a tu familia y comienzas a desesperarte, tienes que salir.")
    time.sleep(3)
    choice_3 = input("¿Ahora si quieres ver tus herramientas? (si/no): ")

for herramienta in herramientas:
    print()
    print(herramienta)
    print()
  

choice_4=input("¿Cuál de tus heramientas quieres usar? foto, llave 1, llave 2, silla")

while choice_4 != "silla":

    if choice_4 == "foto":
        print()
        print("Ves la foto de una familia feliz con un hijo pequeño.")
        print()
        time.sleep(2)
        print("Luego de un rato mirando la foto te das cuenta de que reconoces el lugar")
        print()
        time.sleep(2)
        print("Es la casa de tu infancia y las personas en la foto son de tu familia")
        print("¡Necesitas salir lo antes posible!")
        time.sleep(3)
        print()
        choice_4=input("¿Quieres usar otra herramienta? llave 1,llave 2,silla: ")
    if choice_4 == "llave 1":
        print()
        time.sleep(2)
        print("Tienes la llave que abrió tu cadena, pero no alcanzas la caja.")
        time.sleep(2)
        print()
        time.sleep(3)
        choice_4=input("¿Quieres usar otra herramienta? foto, llave 2, silla: ")
    if choice_4 == "llave 2":
        print()
        time.sleep(2)
        print("Tienes una llave que no has utilizado pero no alcanzas la caja.")
        time.sleep(2)
        print()
        time.sleep(3)
        choice_4=input("¿Quieres usar otra herramienta? foto, llave1, silla: ")

        winsound.PlaySound("Sound",winsound.SND_ASYNC)
#os.system("afplay Sound.wav&") 

print()
print("¡Muy bien! Con la silla puedes alcanzar la caja del techo, la abres con la llave2")
time.sleep(1)
print("y encuentras varias hojas de papel, cada una tiene un número rojo escrito en grande y un acertijo.")
time.sleep(2)
print("Los número son:")
print()
time.sleep(1)
print("0")
time.sleep(1)
print("7")
time.sleep(1)
print("2")
time.sleep(1)
print("5")
time.sleep(2)
print()
print("Te das cuenta de que esos números pueden ayudarte a abrir la puerta")
print("El acertijo es el siguiente:")
print("Tienes una hoja de papel y dos làpices ")
time.sleep(3)
print()

choice_5=input("¿Qué combinacion quieres intentar en la puerta? Sepára los números con comas (,): ")

while choice_5 != puerta:
    print()
    print("No es la combinaciòn correcta")
    time.sleep(2)
    print()
    choice_5=input("¿Qué otra combinacion quieres intentar?")
    
print()
time.sleep(2)
print("...")
time.sleep(1)
print("....")
time.sleep(2)
print("La pantalla se pone verde.")
print()
time.sleep(1)
print("¡Lo hiciste increíble! Felicidades!")
time.sleep(1)
print("¡¡¡ERES LIBRE!!!")
print()
path="Free.jpg"
display(Image.open(path))




#delay=input("Finish")

winsound.PlaySound(None, winsound.SND_PURGE)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x267 at 0x2006934B080>
# Bienvenido.
#
# Has despertado en una habitación a obscuras,
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x241 at 0x20069485438>
# tu pie derecho está encadenado a la pared detrás de ti.
#
# No puedes ver nada pero sientes una silla a tu lado.
#
# Comienzas a tocar a tu alrededor para reconocer el espacio.
#
# Sientes el interruptor en una de las paredes y logras encender
# una luz color ambar que ilumina muy poco.
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x190 at 0x200694854A8>
# Tus ojos se acostumbran lentamente a la nueva luz y te das cuenta
# que algo debajo de ti se mueve, es una tabla suelta en el piso.
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x343 at 0x20069485438>
# ¿Qué quieres hacer? quitar la tabla (1) o sentarte en la silla(2): 2
#
# Te sientes confundido y no puedes ver mucho, sigues algo aturdido,
# ...
